# %%
import pandas as pd
import mysql.connector as sql

# %%
connection = sql.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='ecommerce'
)
df = pd.read_sql("SELECT * FROM orders", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_8884\3061886083.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM orders", connection)

# %%
mapeamento = {
     'delivery_date' : 'Ainda não entregue',
     'reason_for_cancellation' : 'Pedido não cancelado'
}
df_tratado = df.fillna(mapeamento)
df_tratado
# Out:
#    orders_id  customer_id        status coupon_code  order_date  \
# 0         10            1    Finalizada        None  2025-06-01
# 1         11            3  Em andamento        None        None
# 2         12            2     Cancelada        None        None
# 3         13            2    Finalizada        None  2026-02-06
# 4         14            7    Finalizada        None  2025-06-01
# 5         15            9    Finalizada        None  2025-06-01
# 6         16            5    Finalizada        None  2025-06-01
# 7         17            6    Finalizada        None  2025-06-11
# 8         18            8    Finalizada        None  2025-06-11
#
#         delivery_date reason_for_cancellation
# 0          2025-07-01    Pedido não cancelado
# 1  Ainda não entregue    Pedido não cancelado
# 2  Ainda não entregue          Falta de Saldo
# 3          2026-03-06    Pedido não cancelado
# 4          2025-07-01    Pedido não cancelado
# 5          2025-07-01    Pedido não cancelado
# 6          2025-07-01    Pedido não cancelado
# 7          2025-07-11    Pedido não cancelado
# 8          2026-07-01    Pedido não cancelado
