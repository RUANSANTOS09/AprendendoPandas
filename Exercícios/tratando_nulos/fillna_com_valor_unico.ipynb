# %%
import pandas as pd
import mysql.connector as sql

# %%
connection = sql.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='ecommerce'
)
df = pd.read_sql("SELECT * FROM orders", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_7728\3061886083.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM orders", connection)

# %%
df['coupon_code'] = df['coupon_code'].fillna('Sem cupom')
df
# Out:
#    orders_id  customer_id        status coupon_code  order_date delivery_date  \
# 0         10            1    Finalizada   Sem cupom  2025-06-01    2025-07-01
# 1         11            3  Em andamento   Sem cupom        None          None
# 2         12            2     Cancelada   Sem cupom        None          None
# 3         13            2    Finalizada   Sem cupom  2026-02-06    2026-03-06
# 4         14            7    Finalizada   Sem cupom  2025-06-01    2025-07-01
# 5         15            9    Finalizada   Sem cupom  2025-06-01    2025-07-01
# 6         16            5    Finalizada   Sem cupom  2025-06-01    2025-07-01
# 7         17            6    Finalizada   Sem cupom  2025-06-11    2025-07-11
# 8         18            8    Finalizada   Sem cupom  2025-06-11    2026-07-01
#
#   reason_for_cancellation
# 0                     NaN
# 1                     NaN
# 2          Falta de Saldo
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
