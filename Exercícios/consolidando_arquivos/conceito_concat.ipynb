# %%
import pandas as pd
import mysql.connector as sql

# %%
connection = sql.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='ecommerce'
)

# %%
df_finalizada = pd.read_sql("SELECT * FROM orders WHERE status = 'Finalizada'", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_1904\525854398.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_finalizada = pd.read_sql("SELECT * FROM orders WHERE status = 'Finalizada'", connection)

# %%
df_em_andamento = pd.read_sql("SELECT * FROM orders WHERE status = 'Em andamento'", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_1904\1754652089.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_em_andamento = pd.read_sql("SELECT * FROM orders WHERE status = 'Em andamento'", connection)

# %%
df_cancelada  = pd.read_sql("SELECT * FROM orders WHERE status = 'Cancelada'",connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_1904\3690935839.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_cancelada  = pd.read_sql("SELECT * FROM orders WHERE status = 'Cancelada'",connection)

# %%
pedidos_consolidados = pd.concat([df_finalizada, df_em_andamento, df_cancelada])

# %%
print(len(pedidos_consolidados))
# Out:
# 9

# %% [markdown]
# IGNORE_INDEX

# %%
print(pedidos_consolidados.index)
# Out:
# Index([0, 1, 2, 3, 4, 5, 6, 0, 0], dtype='int64')

# %%
pedidos_consolidados_v2 = pd.concat([df_finalizada, df_em_andamento, df_cancelada], ignore_index=True)

# %%
print(pedidos_consolidados_v2.index)
# Out:
# RangeIndex(start=0, stop=9, step=1)
