# %%
import pandas as pd
import mysql.connector as sql

# %%
connection = sql.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='customers_raw_import'
)
df = pd.read_sql("SELECT * FROM customers", connection)

# %%
df.duplicated(subset=['cpf']) # Diagnóstico de quais linhas são duplicatas
# Out:
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# 5    False
# dtype: bool

# %%
df = df.drop_duplicates(subset=['cpf'], keep='last')

# %%
print(df.duplicated(subset=['cpf']).sum())
# Out:
# 0
