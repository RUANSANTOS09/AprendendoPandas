# %%
import pandas as pd
import mysql.connector as sql

# %%
connection = sql.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='ecommerce'
)
df = pd.read_sql("SELECT orders_raw_id, first_name FROM orders_raw_import", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_17060\76654933.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT orders_raw_id, first_name FROM orders_raw_import", connection)

# %%
df['first_name'] = df['first_name'].str.strip().str.title()

# %%
df.duplicated(subset=['orders_raw_id'])
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# dtype: bool
