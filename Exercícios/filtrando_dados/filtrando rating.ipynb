# %%
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    passwd = 'Ruan81527733',
    database = "sakila",
    charset = 'utf8mb4'
)
df = pd.read_sql("SELECT * FROM film", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_21196\1936843401.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM film", connection)

# %%
itens = ['PG', 'PG-13', 'R']
df_filter_rating = df.loc[df['rating'].isin(itens)]
df_filter_rating.head(10)
# Out:
#     film_id             title  \
# 0         1  ACADEMY DINOSAUR
# 5         6      AGENT TRUMAN
# 6         7   AIRPLANE SIERRA
# 7         8   AIRPORT POLLOCK
# 8         9     ALABAMA DEVIL
# 11       12    ALASKA PHANTOM
# 12       13       ALI FOREVER
# 16       17        ALONE TRIP
# 17       18     ALTER VICTORY
# 18       19      AMADEUS HOLY
#
#                                           description  release_year  \
# 0   A Epic Drama of a Feminist And a Mad Scientist...          2006
# 5   A Intrepid Panorama of a Robot And a Boy who m...          2006
# 6   A Touching Saga of a Hunter And a Butler who m...          2006
# 7   A Epic Tale of a Moose And a Girl who must Con...          2006
# 8   A Thoughtful Panorama of a Database Administra...          2006
# 11  A Fanciful Saga of a Hunter And a Pastry Chef ...          2006
# 12  A Action-Packed Drama of a Dentist And a Croco...          2006
# 16  A Fast-Paced Character Study of a Composer And...          2006
# ...
