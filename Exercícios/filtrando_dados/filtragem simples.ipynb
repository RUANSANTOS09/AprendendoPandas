# %%
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Ruan81527733",
    database="mechanic"
)
df = pd.read_sql("SELECT * FROM services_performed", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_14816\4119512453.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM services_performed", connection)

# %%
df_expensive_services = df.loc[df['price'] > 20000]
df_expensive_services.head()
# Out:
#    services_performed_id                                   services  \
# 0                      1      Troca dos discos e pastilhas de freio
# 2                      3                        Reparo da suspensão
# 3                      4  Manutenção da refrigeração da transmissão
#
#    mechanic_id  vehicles_id    price service_date
# 0            7            1  45000.0   2028-03-28
# 2            5            3  25000.0   2029-11-08
# 3            2            4  35000.0   2027-07-30
