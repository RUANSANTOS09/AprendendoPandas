# %%
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database='mechanic'
)
df = pd.read_sql('SELECT * FROM info_problem_price', connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_14072\4155400872.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM info_problem_price', connection)

# %%
df_expensive_transmission_services = df.loc[(df['problem_description']).str.contains('transmissão') & (df['price'] > 20000)]
df_expensive_transmission_services
# Out:
#    vehicles_id                  model                  problem_description  \
# 3            4  Lamborghini Aventador  Superaquecimento da transmissão ISR
#
#      price
# 3  35000.0
