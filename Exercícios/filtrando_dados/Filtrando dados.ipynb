# %%
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    host = 'localhost',
    user = 'root',
    passwd = 'Ruan81527733',
    database = "sakila",
    charset = 'utf8mb4'
)
df = pd.read_sql("SELECT * FROM film", connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_10236\1936843401.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql("SELECT * FROM film", connection)

# %%
df_filter_film = df.loc[df['rental_rate'] > 3]
df_filter_film.head(10)
# Out:
#     film_id                 title  \
# 1         2        ACE GOLDFINGER
# 6         7       AIRPLANE SIERRA
# 7         8       AIRPORT POLLOCK
# 9        10      ALADDIN CALENDAR
# 12       13           ALI FOREVER
# 19       20   AMELIE HELLFIGHTERS
# 20       21       AMERICAN CIRCUS
# 27       28           ANTHEM LUKE
# 30       31         APACHE DIVINE
# 31       32  APOCALYPSE FLAMINGOS
#
#                                           description  release_year  \
# 1   A Astounding Epistle of a Database Administrat...          2006
# 6   A Touching Saga of a Hunter And a Butler who m...          2006
# 7   A Epic Tale of a Moose And a Girl who must Con...          2006
# 9   A Action-Packed Tale of a Man And a Lumberjack...          2006
# 12  A Action-Packed Drama of a Dentist And a Croco...          2006
# 19  A Boring Drama of a Woman And a Squirrel who m...          2006
# 20  A Insightful Drama of a Girl And a Astronaut w...          2006
# 27  A Touching Panorama of a Waitress And a Woman ...          2006
# 30  A Awe-Inspiring Reflection of a Pastry Chef An...          2006
# 31  A Astounding Story of a Dog And a Squirrel who...          2006
#
#     language_id original_language_id  rental_duration  rental_rate  length  \
# 1             1                 None                3         4.99      48
# 6             1                 None                6         4.99      62
# 7             1                 None                6         4.99      54
# 9             1                 None                6         4.99      63
# 12            1                 None                4         4.99     150
# 19            1                 None                4         4.99      79
# 20            1                 None                3         4.99     129
# 27            1                 None                5         4.99      91
# 30            1                 None                5         4.99      92
# 31            1                 None                6         4.99     119
#
#     replacement_cost rating  \
# 1              12.99      G
# 6              28.99  PG-13
# 7              15.99      R
# 9              24.99  NC-17
# 12             21.99     PG
# 19             23.99      R
# 20             17.99      R
# 27             16.99  PG-13
# 30             16.99  NC-17
# 31             11.99      R
#
#                                      special_features         last_update
# 1                          {Deleted Scenes, Trailers} 2006-02-15 05:03:42
# 6                          {Deleted Scenes, Trailers} 2006-02-15 05:03:42
# 7                                          {Trailers} 2006-02-15 05:03:42
# 9                          {Deleted Scenes, Trailers} 2006-02-15 05:03:42
# 12                {Behind the Scenes, Deleted Scenes} 2006-02-15 05:03:42
# 19  {Commentaries, Behind the Scenes, Deleted Scenes} 2006-02-15 05:03:42
# 20                  {Commentaries, Behind the Scenes} 2006-02-15 05:03:42
# 27                {Behind the Scenes, Deleted Scenes} 2006-02-15 05:03:42
# 30  {Commentaries, Behind the Scenes, Deleted Scenes} 2006-02-15 05:03:42
# 31                           {Commentaries, Trailers} 2006-02-15 05:03:42
