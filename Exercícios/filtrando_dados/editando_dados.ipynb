# %%
import pandas as pd
import mysql.connector

# %%
connection = mysql.connector.connect(
    host='localhost',
    user='root',
    password='Ruan81527733',
    database= 'mechanic'
)
df = pd.read_sql('SELECT * FROM info_price_name', connection)
# Out:
# C:\Users\ruans\AppData\Local\Temp\ipykernel_8012\1864397361.py:7: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql('SELECT * FROM info_price_name', connection)

# %%
mechanics = ['Pedro', 'Leticia', 'Valdemir']
df_filter_mechanics = df.loc[df['name'].isin(mechanics)]

# %%
df_filter_mechanics
# Out:
#        name    price
# 1   Leticia  12000.0
# 2  Valdemir  25000.0
# 4     Pedro  18000.0
