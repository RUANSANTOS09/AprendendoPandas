# %%
from parso import normalizer

"""
Tipo inteiro (int)
Ponto Flutuante ou Decimal (float)
String (str)
String (Object)
Data (datetime)
"""

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\ruans\OneDrive\Documentos\Material curso engenharia de dados\Python+-+SGBDS\Arquivos\05.+SQL+Server\05. SQL Server\Origem\Origem\arquivos_csv\Clientes.csv", delimiter=',')
df
# Out:
#     id           created_at first_name last_name                 email  \
# 0    0  2017-11-01 14:45:41      Marta     Jesus                   NaN
# 1    1  2017-10-16 00:50:39      Luana   Almeida                   NaN
# 2    2  2018-06-16 17:51:29      Frida    Mendes   frida@meu_email.com
# 3    3  2018-01-17 03:02:58    Daniela   Avelino   daniela@exemplo.com
# 4    4  2018-08-06 07:24:16    Romário  Teixeira                   NaN
# ..  ..                  ...        ...       ...                   ...
# 95  95  2018-10-01 11:35:59    Mariana      Rosa   mariana@usuario.com
# 96  96  2018-01-23 19:14:21      Paulo    Câmara     paulo@usuario.com
# 97  97  2018-07-04 18:45:41      Marta      Góes       marta@teste.com
# 98  98  2018-01-24 16:21:06     Cibele     Costa  cibele@meu_email.com
# 99  99  2018-07-24 08:26:27    Jéssica     Jesus   jéssica@usuario.com
#
#      cell_phone country              state  \
# 0   9 9102-7834  Brasil               Acre
# ...

# %%
print(df['id'].dtype)
# Out:
# int64

# %%
print(df['created_at'].dtypes)
print(df['first_name'].dtypes)
# Out:
# str
# str

# %%
for coluna in df.columns:
    print(f'coluna: {coluna}, Tipo de dados: {df[coluna].dtypes}')
# Out:
# coluna: id, Tipo de dados: int64
# coluna: created_at, Tipo de dados: str
# coluna: first_name, Tipo de dados: str
# coluna: last_name, Tipo de dados: str
# coluna: email, Tipo de dados: str
# coluna: cell_phone, Tipo de dados: str
# coluna: country, Tipo de dados: str
# coluna: state, Tipo de dados: str
# coluna: street, Tipo de dados: str
# coluna: number, Tipo de dados: float64
# coluna: additionals, Tipo de dados: str

# %% [markdown]
# Convertendo Dados

# %%
df['id'] = df['id'].astype(float)

# %%
print(df['id'].dtype)
# Out:
# float64

# %%
for coluna in df.columns:
    print(f'Coluna: {coluna}, Tipo de dado: {df[coluna].dtypes}')
# Out:
# Coluna: id, Tipo de dado: float64
# Coluna: created_at, Tipo de dado: str
# Coluna: first_name, Tipo de dado: str
# Coluna: last_name, Tipo de dado: str
# Coluna: email, Tipo de dado: str
# Coluna: cell_phone, Tipo de dado: str
# Coluna: country, Tipo de dado: str
# Coluna: state, Tipo de dado: str
# Coluna: street, Tipo de dado: str
# Coluna: number, Tipo de dado: float64
# Coluna: additionals, Tipo de dado: str
